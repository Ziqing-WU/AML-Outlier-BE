# %% [markdown]
# Outlier detection for aircraft system data

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope

# %%
dataset = pd.read_csv("dataset.csv")
dataset.head()
# Out:
#   day_cycle_window        p1        p2        p3        p4        p5       p6  \
# 0            1_1_1 -0.805191 -1.141993 -1.328327 -1.516693 -1.373962 -0.80827
# 1            1_1_1 -0.805191 -1.134902 -1.320393 -1.505848 -1.361560 -0.80784
# 2            1_1_1 -0.805191 -1.117304 -1.307167 -1.505848 -1.361560 -0.80784
# 3            1_1_1 -0.814231 -1.114206 -1.287593 -1.442302 -1.287565 -0.80784
# 4            1_1_1 -0.848104 -1.112276 -1.285393 -1.429076 -1.270722 -0.80784
#
#          p7        p8        p9       p10       p11
# 0 -1.070547 -0.504352  2.807146  0.495528 -1.246737
# 1 -1.064212 -0.516000  2.894177  0.494467 -1.244472
# 2 -1.064212 -0.516000  2.981904  0.429370 -1.244472
# 3 -1.045557 -0.516000  3.063298  0.348056 -1.244472
# 4 -1.017575 -0.664906  3.049237  0.118828 -1.270237

# %%
dataset.describe()
# Out:
#                   p1             p2             p3             p4  \
# count  162702.000000  162702.000000  162702.000000  162702.000000
# mean        0.000009       0.000011       0.000031       0.000005
# std         0.999950       0.999925       0.999961       0.999925
# min        -3.211980      -3.395387      -3.325651      -3.378450
# 25%        -0.678808      -0.482716      -0.629123      -0.491585
# 50%         0.041883       0.180360       0.041442       0.147397
# 75%         0.743973       0.656920       0.659246       0.636887
# max         5.013899       6.260782       8.652950       8.359670
#
#                   p5             p6             p7             p8  \
# count  162702.000000  162702.000000  162702.000000  162702.000000
# mean        0.000016      -0.000005      -0.000002       0.000003
# std         0.999963       0.999926       0.999950       0.999949
# min        -3.281286      -4.200181      -3.898025      -3.524957
# 25%        -0.612334      -0.559023      -0.606135      -0.736398
# 50%         0.117040       0.153972       0.186038      -0.012354
# 75%         0.712393       0.685353       0.718237       0.802395
# max         6.424227       5.638259       3.735957       4.667058
#
#                   p9            p10            p11
# count  162702.000000  162702.000000  162702.000000
# mean       -0.000021       0.000026       0.000030
# std         0.997770       0.999686       0.999847
# min       -13.704556     -12.044778      -3.183571
# 25%        -0.593096      -0.498480      -0.658530
# 50%        -0.034882      -0.257635      -0.015437
# 75%         0.508232       0.359773       0.636740
# max         8.203706       5.597387       9.204384

# %%
dataset.groupby(["day_cycle_window"]).describe()
# Out:
#                      p1                                                    \
#                   count      mean       std       min       25%       50%
# day_cycle_window
# 1_1_1             100.0 -1.926141  0.591155 -3.107670 -2.338262 -1.849016
# 1_1_10            100.0  1.204735  0.245958  0.900633  0.982340  1.118294
# 1_1_11            100.0  0.742475  0.133627  0.486868  0.619690  0.800962
# 4_4_95           -0.689974 -0.667265 -0.656346
# 4_4_96           -0.736051 -0.730592 -0.632326
# 4_4_97           -0.741510 -0.739599 -0.731683
# 4_4_98           -0.634510 -0.612673 -0.565724
# 4_4_99           -0.479468 -0.476193 -0.472917
#
# [1637 rows x 88 columns]

# %%
mean_per_window = dataset.groupby(["day_cycle_window"]).mean()
mean_per_window.head()
# Out:
#                         p1        p2        p3        p4        p5        p6  \
# day_cycle_window
# 1_1_1            -1.926141 -2.456284 -2.487394 -2.481230 -2.388674 -1.984092
# 1_1_10            1.204735  1.123558  1.077596  1.128253  1.136183  1.228688
# 1_1_11            0.742475  0.703459  0.680578  0.740626  0.768269  0.736631
# 1_1_12            0.300162  0.289058  0.289114  0.342999  0.396993  0.254292
# 1_1_13            0.140935  0.152487  0.161874  0.200016  0.226986  0.083547
#
#                         p7        p8        p9       p10       p11
# day_cycle_window
# 1_1_1            -2.447148 -1.169837  2.848242 -1.370045 -2.500060
# 1_1_10            1.199106  1.308412 -0.429810 -0.088168  1.016565
# 1_1_11            0.755362  0.783155 -0.429810 -0.091129  0.669938
# 1_1_12            0.324268  0.264819 -0.429810 -0.085217  0.303699
# 1_1_13            0.170042  0.068720 -0.429810 -0.089727  0.186059

# %%
mean_per_window.boxplot()
# Out:
# <AxesSubplot:>

# %%
n_len = len(mean_per_window.index)
p = 0.7
mean_per_window_train = mean_per_window[:int(n_len*p)]
mean_per_window_test = mean_per_window[int(n_len*p):]

# %% [markdown]
# Outlier detection

# %%
clf = IsolationForest(behaviour='new', n_estimators=100, contamination=0.15)
clf.fit(mean_per_window_train)
# Out:
# /Users/z.wu/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_iforest.py:255: FutureWarning: 'behaviour' is deprecated in 0.22 and will be removed in 0.24. You should not pass or set this parameter.
#   FutureWarning
# IsolationForest(behaviour='new', contamination=0.15)

# %%
y_pred_train = clf.predict(mean_per_window_train)
y_pred_test = clf.predict(mean_per_window_test)

# %%
score = clf.decision_function(mean_per_window_test)
nb_normal = len(score[score>=0])
nb_anomaly = len(score[score<0])
nb_normal, nb_anomaly
# Out:
# (399, 93)

# %% [markdown]
# Training on the whole dataset

# %%
clf_all = IsolationForest(behaviour='new', n_estimators=100, contamination=0.15)
clf_all.fit(mean_per_window)
y_pred = clf.predict(mean_per_window)
score = clf.decision_function(mean_per_window)
nb_normal = len(score[score>=0])
nb_anomaly = len(score[score<0])
nb_normal, nb_anomaly
# Out:
# /Users/z.wu/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_iforest.py:255: FutureWarning: 'behaviour' is deprecated in 0.22 and will be removed in 0.24. You should not pass or set this parameter.
#   FutureWarning
# (1391, 246)

# %%
clf_ee = EllipticEnvelope(contamination=0.15)
clf_ee.fit(df[['X1','X2']])
